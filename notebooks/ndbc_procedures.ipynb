# %% [markdown]
# ### NDBC buoys
#
#
# There are many options to get the NDBC data on github. I'm using NDBC (https://pypi.org/project/NDBC) lib (pip install NDBC).
#
# 1) I use a list of available buoys at NDBC website (https://www.ndbc.noaa.gov/) to download the stations and execute:\
#    *python getNDBC.py*
#
# 2) Generate a dictionary with the stations list downloaded in order to get the same buoy location to extract from the model (WW3). The dictionary is generated by:\
#    *python getPosNDBC4WW3.py*
#
# 3) The next scritp extract wave data from WW3 acording to the list of positions obtained by buoys. Execute the following:\
#    *python getVarWW3.py*
# 4)
# 5)
